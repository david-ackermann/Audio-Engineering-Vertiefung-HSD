# %% [markdown]
# # Fourier Phasor Explorer
#
# Run the next cell to launch the interactive figure directly inside Jupyter.
#
# The notebook uses the `%matplotlib widget` backend, so the Matplotlib sliders and radio buttons remain interactive in the notebook output.
#
# If Jupyter reports that `widget` is not a recognized backend, install `ipympl` in the same Python environment that runs the notebook.

# %%
import ipympl

# %matplotlib widget
import matplotlib.pyplot as plt

import fourier_phasor_interactive as app

plt.close("all")
app.main()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Optional: launch with Voila
#
# From the project folder:
#
# ```bash
# voila fourier_phasor_notebook.ipynb
# ```
#
# That opens the notebook as a simplified app view without the editable code cells.
